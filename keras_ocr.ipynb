# %%
import matplotlib.pyplot as plt
import keras_ocr
import cv2

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /home/s_r/.keras-ocr/craft_mlt_25k.h5
# WARNING:tensorflow:AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a83378e0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING: AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a83378e0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING:tensorflow:AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a81f70d0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING: AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a81f70d0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING:tensorflow:AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a81f1fa0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING: AutoGraph could not transform <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x7f02a81f1fa0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'defaults'
# WARNING:tensorflow:From /usr/lib/python3.8/site-packages/tensorflow_core/python/keras/backend.py:5809: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Looking for /home/s_r/.keras-ocr/crnn_kurapan.h5

# %%
image = cv2.imread('img.jpg')

images = [keras_ocr.tools.read(image)]

# %%
cv2.imshow("image",image)
cv2.waitKey(0)

# %%
prediction = pipeline.recognize(images)

# %%
prediction
# Out:
# [[('rzx',
#    array([[  0.     ,  91.58203],
#           [395.3291 ,  91.58203],
#           [395.3291 , 166.37402],
#           [  0.     , 166.37402]], dtype=float32)),
#   ('isw',
#    array([[1501.9453 ,  123.63574],
#           [1561.4736 ,  123.63574],
#           [1561.4736 ,  161.79492],
#           [1501.9453 ,  161.79492]], dtype=float32)),
#   ('hr28d0551',
#    array([[ 647.3103 ,  485.4091 ],
#           [1383.9045 ,  383.10437],
#           [1407.2043 ,  550.86383],
#           [ 670.6101 ,  653.1685 ]], dtype=float32)),
#   ('ind',
#    array([[568.2055 , 555.32294],
#           [656.8874 , 542.6541 ],
#           [663.8782 , 591.5894 ],
#           [575.1963 , 604.25824]], dtype=float32)),
#   ('gol',
#    array([[1368.0461 ,  995.6652 ],
#           [1417.5267 ,  998.5758 ],
#           [1415.8635 , 1026.8505 ],
#           [1366.3829 , 1023.93994]], dtype=float32)),
#   ('mechanic',
#    array([[1411.8896 ,  998.24414],
#           [1556.8945 ,  998.24414],
#           [1556.8945 , 1025.7188 ],
#           [1411.8896 , 1025.7188 ]], dtype=float32))]]

# %%
fig,axs = plt.subplots(1,2,figsize=(20,20))
for ax,image,predictions in zip(axs,images,prediction):
    keras_ocr.tools.drawAnnotations(image=image,predictions=predictions,ax=ax)
